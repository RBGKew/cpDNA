# %%
from Bio import SeqIO
from Bio.Seq import Seq
from Bio.SeqRecord import SeqRecord
import os
import pandas as pd
import numpy as np

# %%
def get_qualifier(feature, qualifier):
    try:
        return feature.qualifiers[qualifier][0]
    except:
        return np.nan
def get_features(gb_file):
    seq_dc=[]
    for rec in SeqIO.parse(gb_file, "genbank"):
        for feature in rec.features:
            feat_dc = {'type':feature.type}
            feat_dc['gene'] = get_qualifier(feature,'gene')
            feat_dc['product'] = get_qualifier(feature,'product')
#             feat_dc['info'] = get_qualifier(feature,'info')
            if feat_dc['gene'] is np.nan:
                feat_dc['gene'] = get_qualifier(feature,'note')
            feat_dc['len'] = len(feature.location.extract(rec).seq)
            feat_dc['location'] = str(feature.location)
            feat_dc['seq'] = str(feature.location.extract(rec).seq)
            seq_dc.append(feat_dc)
    return pd.DataFrame(seq_dc)

# %%
def write_fasta(seq_df, sample_stats, fasta_file):
    Records = []
    for idx, row in seq_df.iterrows():
        record = SeqRecord( Seq(row.seq), id=sample_stats['Sample'].replace('-','_') + '-' + row.gene.replace('-','_'), 
                description= ';product=' + str(row['product']) + ', location=' + str(row['location']) + ';' )
        Records.append(record)
    SeqIO.write(Records,fasta_file,format='fasta')

# %%
ref_dir = 'References/'
all_gb_files = [ref_dir + file for file in os.listdir(ref_dir) if file.endswith(".gb")]
# all_gb_files = ['References/NC_003386.1.gb']
print(len(all_gb_files))

Samples_ls = []
for gb_file in all_gb_files:
    # Get features
    seq_df = get_features(gb_file)

    # Get raw feature stats
    sample_stats={'Sample':gb_file.split('/')[-1].replace('.gb','')}
    sample_stats['Nfeatures_raw']=seq_df.shape[0];sample_stats['Ngenes_raw']=seq_df.gene.nunique()
    feat_raw_stats = seq_df.groupby('type').size().sort_values(ascending=False).to_dict()

    # Removing fragments
    seq_df = seq_df[seq_df.gene.str.contains('-fragment')==False]
    # Keeping CDS, rRNA, repeat_region
    accepted_types = ['CDS','rRNA','tRNA'] # Could add repeat_region
    seq_gene = seq_df[seq_df.type=='gene']
    seq_df = seq_df[seq_df.type.isin(accepted_types)]
    seq_gene = seq_gene[seq_gene.gene.isin(seq_df.gene)==False]
    sample_stats['Nfeatures_sel']=seq_df.shape[0];sample_stats['Ngenes_sel']=seq_df.gene.nunique()

    # Removing duplicates
    sample_stats['Nidentical'] = seq_df[seq_df.duplicated(keep=False)].gene.nunique()
    sample_stats['Nduplicates'] = seq_df[seq_df.duplicated(subset='gene',keep=False)].gene.nunique()
    seq_df = seq_df.sort_values('len',ascending=False).groupby('gene').head(1) # Keep longest sequence per gene
    sample_stats['Nfeatures']=seq_df.shape[0];sample_stats['Ngenes']=seq_df.gene.nunique()
    Samples_ls.append(sample_stats)
    print(sample_stats)
    print(feat_raw_stats)
    print(seq_df.groupby('type').size().sort_values(ascending=False).to_dict())

    seq_df = seq_df.sort_values(['type','gene']).reset_index(drop=True)
    write_fasta(seq_df, sample_stats, fasta_file = gb_file.replace('.gb','_CDS.fasta'))
# Out:
# 124
# {'Sample': 'NC_003386.1', 'Nfeatures_raw': 546, 'Ngenes_raw': 129, 'Nfeatures_sel': 208, 'Ngenes_sel': 119, 'Nidentical': 0, 'Nduplicates': 49, 'Nfeatures': 119, 'Ngenes': 119}
# {'gene': 207, 'CDS': 125, 'exon': 72, 'tRNA': 67, 'intron': 49, 'rRNA': 21, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 81, 'tRNA': 34, 'rRNA': 4}
# {'Sample': 'NC_005086.1', 'Nfeatures_raw': 467, 'Ngenes_raw': 120, 'Nfeatures_sel': 177, 'Ngenes_sel': 115, 'Nidentical': 0, 'Nduplicates': 38, 'Nfeatures': 115, 'Ngenes': 115}
# {'gene': 169, 'CDS': 100, 'exon': 76, 'tRNA': 67, 'intron': 40, 'rRNA': 10, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 80, 'tRNA': 31, 'rRNA': 4}
# {'Sample': 'NC_009962.1', 'Nfeatures_raw': 448, 'Ngenes_raw': 119, 'Nfeatures_sel': 169, 'Ngenes_sel': 114, 'Nidentical': 0, 'Nduplicates': 32, 'Nfeatures': 114, 'Ngenes': 114}
# {'gene': 160, 'CDS': 95, 'exon': 73, 'tRNA': 64, 'intron': 41, 'rRNA': 10, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 31, 'rRNA': 4}
# {'Sample': 'NC_010323.1', 'Nfeatures_raw': 455, 'Ngenes_raw': 121, 'Nfeatures_sel': 170, 'Ngenes_sel': 115, 'Nidentical': 0, 'Nduplicates': 32, 'Nfeatures': 115, 'Ngenes': 115}
# {'gene': 158, 'CDS': 94, 'exon': 80, 'tRNA': 66, 'intron': 42, 'rRNA': 10, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_010654.1', 'Nfeatures_raw': 390, 'Ngenes_raw': 103, 'Nfeatures_sel': 148, 'Ngenes_sel': 96, 'Nidentical': 0, 'Nduplicates': 25, 'Nfeatures': 96, 'Ngenes': 96}
# {'gene': 146, 'tRNA': 69, 'CDS': 63, 'exon': 56, 'intron': 31, 'rRNA': 20, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 58, 'tRNA': 34, 'rRNA': 4}
# {'Sample': 'NC_011156.4', 'Nfeatures_raw': 395, 'Ngenes_raw': 117, 'Nfeatures_sel': 160, 'Ngenes_sel': 111, 'Nidentical': 0, 'Nduplicates': 36, 'Nfeatures': 111, 'Ngenes': 111}
# {'gene': 161, 'CDS': 108, 'tRNA': 46, 'exon': 43, 'intron': 26, 'rRNA': 10, 'source': 1}
# {'CDS': 78, 'tRNA': 29, 'rRNA': 4}
# {'Sample': 'NC_012818.1', 'Nfeatures_raw': 552, 'Ngenes_raw': 129, 'Nfeatures_sel': 213, 'Ngenes_sel': 120, 'Nidentical': 0, 'Nduplicates': 56, 'Nfeatures': 120, 'Ngenes': 120}
# {'gene': 217, 'CDS': 141, 'exon': 67, 'tRNA': 60, 'intron': 42, 'rRNA': 20, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 85, 'tRNA': 31, 'rRNA': 4}
# {'Sample': 'NC_015605.1', 'Nfeatures_raw': 461, 'Ngenes_raw': 121, 'Nfeatures_sel': 173, 'Ngenes_sel': 115, 'Nidentical': 0, 'Nduplicates': 32, 'Nfeatures': 115, 'Ngenes': 115}
# {'gene': 161, 'CDS': 96, 'exon': 79, 'tRNA': 65, 'intron': 43, 'rRNA': 12, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 32, 'rRNA': 4}
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\GenBank\__init__.py:366: BiopythonParserWarning: Attempting to fix invalid location '156533..99712' as it looks like incorrect origin wrapping. Please fix input file, this could have unintended behavior.
#   BiopythonParserWarning,
# {'Sample': 'NC_016986.1', 'Nfeatures_raw': 514, 'Ngenes_raw': 131, 'Nfeatures_sel': 197, 'Ngenes_sel': 126, 'Nidentical': 0, 'Nduplicates': 47, 'Nfeatures': 126, 'Ngenes': 126}
# {'gene': 188, 'CDS': 109, 'exon': 81, 'tRNA': 76, 'intron': 43, 'rRNA': 12, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 85, 'tRNA': 37, 'rRNA': 4}
# {'Sample': 'NC_017006.1', 'Nfeatures_raw': 507, 'Ngenes_raw': 127, 'Nfeatures_sel': 196, 'Ngenes_sel': 120, 'Nidentical': 0, 'Nduplicates': 44, 'Nfeatures': 120, 'Ngenes': 120}
# {'gene': 197, 'CDS': 118, 'exon': 64, 'tRNA': 63, 'intron': 38, 'rRNA': 22, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 84, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_020146.1', 'Nfeatures_raw': 548, 'Ngenes_raw': 131, 'Nfeatures_sel': 213, 'Ngenes_sel': 121, 'Nidentical': 0, 'Nduplicates': 54, 'Nfeatures': 121, 'Ngenes': 121}
# {'gene': 214, 'CDS': 134, 'exon': 67, 'tRNA': 63, 'intron': 43, 'rRNA': 22, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 84, 'tRNA': 33, 'rRNA': 4}
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\GenBank\__init__.py:366: BiopythonParserWarning: Attempting to fix invalid location '165380..84468' as it looks like incorrect origin wrapping. Please fix input file, this could have unintended behavior.
#   BiopythonParserWarning,
# {'Sample': 'NC_020372.1', 'Nfeatures_raw': 452, 'Ngenes_raw': 119, 'Nfeatures_sel': 175, 'Ngenes_sel': 114, 'Nidentical': 0, 'Nduplicates': 41, 'Nfeatures': 114, 'Ngenes': 114}
# {'gene': 166, 'CDS': 101, 'exon': 69, 'tRNA': 63, 'intron': 36, 'rRNA': 12, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 31, 'rRNA': 4}
# {'Sample': 'NC_021426.1', 'Nfeatures_raw': 480, 'Ngenes_raw': 122, 'Nfeatures_sel': 178, 'Ngenes_sel': 115, 'Nidentical': 0, 'Nduplicates': 38, 'Nfeatures': 115, 'Ngenes': 115}
# {'gene': 171, 'CDS': 102, 'exon': 79, 'tRNA': 64, 'intron': 43, 'rRNA': 16, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_022137.1', 'Nfeatures_raw': 540, 'Ngenes_raw': 126, 'Nfeatures_sel': 207, 'Ngenes_sel': 117, 'Nidentical': 0, 'Nduplicates': 55, 'Nfeatures': 117, 'Ngenes': 117}
# {'gene': 210, 'CDS': 138, 'exon': 69, 'tRNA': 57, 'intron': 41, 'rRNA': 20, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 85, 'tRNA': 28, 'rRNA': 4}
# {'Sample': 'NC_022812.1', 'Nfeatures_raw': 468, 'Ngenes_raw': 122, 'Nfeatures_sel': 174, 'Ngenes_sel': 115, 'Nidentical': 0, 'Nduplicates': 34, 'Nfeatures': 115, 'Ngenes': 115}
# {'gene': 164, 'CDS': 96, 'exon': 80, 'tRNA': 66, 'intron': 43, 'rRNA': 14, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_023256.1', 'Nfeatures_raw': 467, 'Ngenes_raw': 123, 'Nfeatures_sel': 175, 'Ngenes_sel': 115, 'Nidentical': 0, 'Nduplicates': 36, 'Nfeatures': 115, 'Ngenes': 115}
# {'gene': 165, 'CDS': 101, 'exon': 78, 'tRNA': 66, 'intron': 42, 'rRNA': 10, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_024157.1', 'Nfeatures_raw': 532, 'Ngenes_raw': 134, 'Nfeatures_sel': 201, 'Ngenes_sel': 124, 'Nidentical': 0, 'Nduplicates': 49, 'Nfeatures': 124, 'Ngenes': 124}
# {'gene': 200, 'CDS': 120, 'exon': 75, 'tRNA': 69, 'intron': 45, 'rRNA': 18, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 85, 'tRNA': 35, 'rRNA': 4}
# {'Sample': 'NC_024158.1', 'Nfeatures_raw': 506, 'Ngenes_raw': 128, 'Nfeatures_sel': 196, 'Ngenes_sel': 118, 'Nidentical': 0, 'Nduplicates': 46, 'Nfeatures': 118, 'Ngenes': 118}
# {'gene': 196, 'CDS': 126, 'exon': 62, 'tRNA': 58, 'intron': 39, 'rRNA': 20, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 85, 'tRNA': 29, 'rRNA': 4}
# {'Sample': 'NC_024728.1', 'Nfeatures_raw': 483, 'Ngenes_raw': 121, 'Nfeatures_sel': 185, 'Ngenes_sel': 115, 'Nidentical': 0, 'Nduplicates': 41, 'Nfeatures': 115, 'Ngenes': 115}
# {'gene': 179, 'CDS': 103, 'exon': 71, 'tRNA': 70, 'intron': 39, 'rRNA': 16, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 32, 'rRNA': 4}
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\GenBank\__init__.py:366: BiopythonParserWarning: Attempting to fix invalid location '159887..87141' as it looks like incorrect origin wrapping. Please fix input file, this could have unintended behavior.
#   BiopythonParserWarning,
# {'Sample': 'NC_024929.1', 'Nfeatures_raw': 483, 'Ngenes_raw': 121, 'Nfeatures_sel': 180, 'Ngenes_sel': 115, 'Nidentical': 0, 'Nduplicates': 37, 'Nfeatures': 115, 'Ngenes': 115}
# {'gene': 167, 'CDS': 102, 'exon': 85, 'tRNA': 66, 'intron': 44, 'rRNA': 14, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_025745.1', 'Nfeatures_raw': 389, 'Ngenes_raw': 119, 'Nfeatures_sel': 155, 'Ngenes_sel': 115, 'Nidentical': 0, 'Nduplicates': 32, 'Nfeatures': 115, 'Ngenes': 115}
# {'gene': 149, 'CDS': 100, 'exon': 53, 'tRNA': 49, 'intron': 29, 'rRNA': 8, 'source': 1}
# {'CDS': 79, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_026295.1', 'Nfeatures_raw': 465, 'Ngenes_raw': 125, 'Nfeatures_sel': 181, 'Ngenes_sel': 121, 'Nidentical': 0, 'Nduplicates': 42, 'Nfeatures': 121, 'Ngenes': 121}
# {'gene': 179, 'CDS': 117, 'exon': 63, 'tRNA': 53, 'intron': 39, 'rRNA': 13, 'source': 1}
# {'CDS': 83, 'tRNA': 34, 'rRNA': 4}
# {'Sample': 'NC_026301.1', 'Nfeatures_raw': 405, 'Ngenes_raw': 107, 'Nfeatures_sel': 153, 'Ngenes_sel': 99, 'Nidentical': 0, 'Nduplicates': 31, 'Nfeatures': 99, 'Ngenes': 99}
# {'gene': 153, 'tRNA': 69, 'CDS': 68, 'exon': 56, 'intron': 30, 'rRNA': 24, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 61, 'tRNA': 34, 'rRNA': 4}
# {'Sample': 'NC_026786.1', 'Nfeatures_raw': 481, 'Ngenes_raw': 122, 'Nfeatures_sel': 183, 'Ngenes_sel': 115, 'Nidentical': 0, 'Nduplicates': 37, 'Nfeatures': 115, 'Ngenes': 115}
# {'gene': 173, 'CDS': 104, 'exon': 78, 'tRNA': 70, 'intron': 41, 'rRNA': 10, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_026847.1', 'Nfeatures_raw': 541, 'Ngenes_raw': 112, 'Nfeatures_sel': 207, 'Ngenes_sel': 104, 'Nidentical': 0, 'Nduplicates': 48, 'Nfeatures': 104, 'Ngenes': 104}
# {'gene': 207, 'CDS': 121, 'exon': 72, 'tRNA': 68, 'intron': 46, 'rRNA': 22, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 73, 'tRNA': 27, 'rRNA': 4}
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\GenBank\__init__.py:366: BiopythonParserWarning: Attempting to fix invalid location '161640..88578' as it looks like incorrect origin wrapping. Please fix input file, this could have unintended behavior.
#   BiopythonParserWarning,
# {'Sample': 'NC_027512.1', 'Nfeatures_raw': 480, 'Ngenes_raw': 126, 'Nfeatures_sel': 187, 'Ngenes_sel': 122, 'Nidentical': 0, 'Nduplicates': 38, 'Nfeatures': 122, 'Ngenes': 122}
# {'gene': 179, 'CDS': 108, 'exon': 72, 'tRNA': 67, 'intron': 37, 'rRNA': 12, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 86, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_027829.1', 'Nfeatures_raw': 472, 'Ngenes_raw': 105, 'Nfeatures_sel': 177, 'Ngenes_sel': 102, 'Nidentical': 0, 'Nduplicates': 42, 'Nfeatures': 102, 'Ngenes': 102}
# {'gene': 174, 'CDS': 95, 'exon': 74, 'tRNA': 66, 'intron': 40, 'rRNA': 22, 'source': 1}
# {'CDS': 68, 'tRNA': 30, 'rRNA': 4}
# {'Sample': 'NC_029427.1', 'Nfeatures_raw': 454, 'Ngenes_raw': 120, 'Nfeatures_sel': 168, 'Ngenes_sel': 114, 'Nidentical': 0, 'Nduplicates': 32, 'Nfeatures': 114, 'Ngenes': 114}
# {'gene': 157, 'CDS': 97, 'exon': 80, 'tRNA': 62, 'intron': 43, 'rRNA': 10, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 31, 'rRNA': 4}
# {'Sample': 'NC_029433.1', 'Nfeatures_raw': 463, 'Ngenes_raw': 121, 'Nfeatures_sel': 174, 'Ngenes_sel': 115, 'Nidentical': 0, 'Nduplicates': 35, 'Nfeatures': 115, 'Ngenes': 115}
# {'gene': 163, 'CDS': 99, 'exon': 78, 'tRNA': 65, 'intron': 43, 'rRNA': 10, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_029970.1', 'Nfeatures_raw': 473, 'Ngenes_raw': 122, 'Nfeatures_sel': 181, 'Ngenes_sel': 115, 'Nidentical': 0, 'Nduplicates': 38, 'Nfeatures': 115, 'Ngenes': 115}
# {'gene': 174, 'CDS': 99, 'exon': 72, 'tRNA': 70, 'intron': 39, 'rRNA': 14, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_030601.1', 'Nfeatures_raw': 462, 'Ngenes_raw': 121, 'Nfeatures_sel': 175, 'Ngenes_sel': 114, 'Nidentical': 0, 'Nduplicates': 38, 'Nfeatures': 114, 'Ngenes': 114}
# {'gene': 164, 'CDS': 100, 'exon': 77, 'tRNA': 65, 'intron': 40, 'rRNA': 11, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 78, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_033874.1', 'Nfeatures_raw': 512, 'Ngenes_raw': 128, 'Nfeatures_sel': 200, 'Ngenes_sel': 122, 'Nidentical': 0, 'Nduplicates': 48, 'Nfeatures': 122, 'Ngenes': 122}
# {'gene': 193, 'CDS': 116, 'exon': 71, 'tRNA': 68, 'intron': 43, 'rRNA': 16, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 86, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_033878.1', 'Nfeatures_raw': 456, 'Ngenes_raw': 121, 'Nfeatures_sel': 170, 'Ngenes_sel': 114, 'Nidentical': 0, 'Nduplicates': 35, 'Nfeatures': 114, 'Ngenes': 114}
# {'gene': 161, 'CDS': 96, 'exon': 76, 'tRNA': 65, 'intron': 43, 'rRNA': 10, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 31, 'rRNA': 4}
# {'Sample': 'NC_034685.1', 'Nfeatures_raw': 435, 'Ngenes_raw': 119, 'Nfeatures_sel': 168, 'Ngenes_sel': 116, 'Nidentical': 0, 'Nduplicates': 33, 'Nfeatures': 116, 'Ngenes': 116}
# {'gene': 160, 'CDS': 94, 'exon': 65, 'tRNA': 62, 'intron': 39, 'rRNA': 14, 'source': 1}
# {'CDS': 80, 'tRNA': 32, 'rRNA': 4}
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\GenBank\__init__.py:366: BiopythonParserWarning: Attempting to fix invalid location '153920..83865' as it looks like incorrect origin wrapping. Please fix input file, this could have unintended behavior.
#   BiopythonParserWarning,
# {'Sample': 'NC_034686.1', 'Nfeatures_raw': 470, 'Ngenes_raw': 122, 'Nfeatures_sel': 180, 'Ngenes_sel': 115, 'Nidentical': 0, 'Nduplicates': 35, 'Nfeatures': 115, 'Ngenes': 115}
# {'gene': 171, 'CDS': 102, 'exon': 73, 'tRNA': 69, 'intron': 40, 'rRNA': 10, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_034942.1', 'Nfeatures_raw': 443, 'Ngenes_raw': 123, 'Nfeatures_sel': 173, 'Ngenes_sel': 120, 'Nidentical': 0, 'Nduplicates': 40, 'Nfeatures': 120, 'Ngenes': 120}
# {'gene': 169, 'CDS': 110, 'exon': 64, 'tRNA': 56, 'intron': 34, 'rRNA': 9, 'source': 1}
# {'CDS': 82, 'tRNA': 34, 'rRNA': 4}
# {'Sample': 'NC_035050.1', 'Nfeatures_raw': 492, 'Ngenes_raw': 120, 'Nfeatures_sel': 195, 'Ngenes_sel': 114, 'Nidentical': 0, 'Nduplicates': 38, 'Nfeatures': 114, 'Ngenes': 114}
# {'gene': 188, 'CDS': 114, 'tRNA': 70, 'exon': 68, 'intron': 35, 'rRNA': 12, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 78, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_035499.1', 'Nfeatures_raw': 464, 'Ngenes_raw': 121, 'Nfeatures_sel': 178, 'Ngenes_sel': 113, 'Nidentical': 0, 'Nduplicates': 35, 'Nfeatures': 113, 'Ngenes': 113}
# {'gene': 172, 'CDS': 101, 'exon': 70, 'tRNA': 68, 'intron': 38, 'rRNA': 10, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 30, 'rRNA': 4}
# {'Sample': 'NC_035545.1', 'Nfeatures_raw': 457, 'Ngenes_raw': 123, 'Nfeatures_sel': 172, 'Ngenes_sel': 116, 'Nidentical': 0, 'Nduplicates': 34, 'Nfeatures': 116, 'Ngenes': 116}
# {'gene': 162, 'CDS': 97, 'exon': 76, 'tRNA': 66, 'intron': 41, 'rRNA': 10, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 80, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_035807.1', 'Nfeatures_raw': 545, 'Ngenes_raw': 116, 'Nfeatures_sel': 218, 'Ngenes_sel': 107, 'Nidentical': 0, 'Nduplicates': 60, 'Nfeatures': 107, 'Ngenes': 107}
# {'gene': 221, 'CDS': 148, 'exon': 58, 'tRNA': 53, 'intron': 36, 'rRNA': 24, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 77, 'tRNA': 26, 'rRNA': 4}
# {'Sample': 'NC_035854.1', 'Nfeatures_raw': 521, 'Ngenes_raw': 124, 'Nfeatures_sel': 215, 'Ngenes_sel': 117, 'Nidentical': 0, 'Nduplicates': 60, 'Nfeatures': 117, 'Ngenes': 117}
# {'gene': 217, 'CDS': 142, 'tRNA': 61, 'exon': 49, 'intron': 31, 'rRNA': 16, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 85, 'tRNA': 28, 'rRNA': 4}
# {'Sample': 'NC_036135.1', 'Nfeatures_raw': 447, 'Ngenes_raw': 120, 'Nfeatures_sel': 169, 'Ngenes_sel': 114, 'Nidentical': 0, 'Nduplicates': 34, 'Nfeatures': 114, 'Ngenes': 114}
# {'gene': 160, 'CDS': 95, 'exon': 73, 'tRNA': 64, 'intron': 40, 'rRNA': 10, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 31, 'rRNA': 4}
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\GenBank\__init__.py:366: BiopythonParserWarning: Attempting to fix invalid location '154782..89286' as it looks like incorrect origin wrapping. Please fix input file, this could have unintended behavior.
#   BiopythonParserWarning,
# {'Sample': 'NC_036154.1', 'Nfeatures_raw': 459, 'Ngenes_raw': 122, 'Nfeatures_sel': 176, 'Ngenes_sel': 115, 'Nidentical': 0, 'Nduplicates': 36, 'Nfeatures': 115, 'Ngenes': 115}
# {'gene': 169, 'CDS': 97, 'exon': 70, 'tRNA': 70, 'intron': 38, 'rRNA': 10, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_036304.1', 'Nfeatures_raw': 443, 'Ngenes_raw': 123, 'Nfeatures_sel': 168, 'Ngenes_sel': 115, 'Nidentical': 0, 'Nduplicates': 33, 'Nfeatures': 115, 'Ngenes': 115}
# {'gene': 158, 'CDS': 98, 'exon': 72, 'tRNA': 62, 'intron': 38, 'rRNA': 10, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 32, 'rRNA': 4}
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\GenBank\__init__.py:366: BiopythonParserWarning: Attempting to fix invalid location '159659..88064' as it looks like incorrect origin wrapping. Please fix input file, this could have unintended behavior.
#   BiopythonParserWarning,
# {'Sample': 'NC_036416.1', 'Nfeatures_raw': 476, 'Ngenes_raw': 122, 'Nfeatures_sel': 178, 'Ngenes_sel': 115, 'Nidentical': 0, 'Nduplicates': 36, 'Nfeatures': 115, 'Ngenes': 115}
# {'gene': 168, 'CDS': 96, 'exon': 80, 'tRNA': 68, 'intron': 43, 'rRNA': 16, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_036660.1', 'Nfeatures_raw': 475, 'Ngenes_raw': 122, 'Nfeatures_sel': 180, 'Ngenes_sel': 115, 'Nidentical': 0, 'Nduplicates': 35, 'Nfeatures': 115, 'Ngenes': 115}
# {'gene': 172, 'CDS': 100, 'exon': 75, 'tRNA': 68, 'intron': 39, 'rRNA': 16, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 78, 'tRNA': 33, 'rRNA': 4}
# {'Sample': 'NC_036960.1', 'Nfeatures_raw': 481, 'Ngenes_raw': 123, 'Nfeatures_sel': 180, 'Ngenes_sel': 115, 'Nidentical': 0, 'Nduplicates': 35, 'Nfeatures': 115, 'Ngenes': 115}
# {'gene': 171, 'CDS': 101, 'exon': 79, 'tRNA': 68, 'intron': 43, 'rRNA': 14, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_037151.1', 'Nfeatures_raw': 447, 'Ngenes_raw': 121, 'Nfeatures_sel': 168, 'Ngenes_sel': 115, 'Nidentical': 0, 'Nduplicates': 31, 'Nfeatures': 115, 'Ngenes': 115}
# {'gene': 157, 'CDS': 92, 'exon': 76, 'tRNA': 66, 'intron': 41, 'rRNA': 10, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_037504.1', 'Nfeatures_raw': 466, 'Ngenes_raw': 126, 'Nfeatures_sel': 175, 'Ngenes_sel': 117, 'Nidentical': 0, 'Nduplicates': 35, 'Nfeatures': 117, 'Ngenes': 117}
# {'gene': 167, 'CDS': 99, 'exon': 74, 'tRNA': 65, 'intron': 40, 'rRNA': 16, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 81, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_037845.1', 'Nfeatures_raw': 460, 'Ngenes_raw': 122, 'Nfeatures_sel': 176, 'Ngenes_sel': 116, 'Nidentical': 0, 'Nduplicates': 37, 'Nfeatures': 116, 'Ngenes': 116}
# {'gene': 167, 'CDS': 98, 'exon': 73, 'tRNA': 68, 'intron': 39, 'rRNA': 10, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 80, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_037885.1', 'Nfeatures_raw': 470, 'Ngenes_raw': 120, 'Nfeatures_sel': 177, 'Ngenes_sel': 115, 'Nidentical': 0, 'Nduplicates': 35, 'Nfeatures': 115, 'Ngenes': 115}
# {'gene': 167, 'CDS': 99, 'exon': 79, 'tRNA': 66, 'intron': 42, 'rRNA': 12, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 32, 'rRNA': 4}
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\GenBank\__init__.py:366: BiopythonParserWarning: Attempting to fix invalid location '163091..87267' as it looks like incorrect origin wrapping. Please fix input file, this could have unintended behavior.
#   BiopythonParserWarning,
# {'Sample': 'NC_037948.1', 'Nfeatures_raw': 478, 'Ngenes_raw': 122, 'Nfeatures_sel': 178, 'Ngenes_sel': 115, 'Nidentical': 0, 'Nduplicates': 38, 'Nfeatures': 115, 'Ngenes': 115}
# {'gene': 171, 'CDS': 102, 'exon': 78, 'tRNA': 64, 'intron': 42, 'rRNA': 16, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_038057.1', 'Nfeatures_raw': 463, 'Ngenes_raw': 121, 'Nfeatures_sel': 173, 'Ngenes_sel': 115, 'Nidentical': 0, 'Nduplicates': 34, 'Nfeatures': 115, 'Ngenes': 115}
# {'gene': 161, 'CDS': 96, 'exon': 81, 'tRNA': 67, 'intron': 43, 'rRNA': 10, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_038074.1', 'Nfeatures_raw': 527, 'Ngenes_raw': 123, 'Nfeatures_sel': 204, 'Ngenes_sel': 122, 'Nidentical': 0, 'Nduplicates': 51, 'Nfeatures': 122, 'Ngenes': 122}
# {'gene': 206, 'CDS': 126, 'exon': 71, 'tRNA': 64, 'intron': 41, 'rRNA': 18, 'source': 1}
# {'CDS': 85, 'tRNA': 33, 'rRNA': 4}
# {'Sample': 'NC_038093.1', 'Nfeatures_raw': 468, 'Ngenes_raw': 122, 'Nfeatures_sel': 174, 'Ngenes_sel': 115, 'Nidentical': 0, 'Nduplicates': 37, 'Nfeatures': 115, 'Ngenes': 115}
# {'gene': 163, 'CDS': 97, 'exon': 81, 'tRNA': 65, 'intron': 43, 'rRNA': 14, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_039155.1', 'Nfeatures_raw': 466, 'Ngenes_raw': 125, 'Nfeatures_sel': 183, 'Ngenes_sel': 123, 'Nidentical': 0, 'Nduplicates': 41, 'Nfeatures': 123, 'Ngenes': 123}
# {'gene': 185, 'CDS': 107, 'tRNA': 64, 'exon': 61, 'intron': 32, 'rRNA': 16, 'source': 1}
# {'CDS': 85, 'tRNA': 34, 'rRNA': 4}
# {'Sample': 'NC_039395.1', 'Nfeatures_raw': 462, 'Ngenes_raw': 122, 'Nfeatures_sel': 174, 'Ngenes_sel': 115, 'Nidentical': 0, 'Nduplicates': 37, 'Nfeatures': 115, 'Ngenes': 115}
# {'gene': 166, 'CDS': 97, 'exon': 75, 'tRNA': 65, 'intron': 40, 'rRNA': 14, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 32, 'rRNA': 4}
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\GenBank\__init__.py:366: BiopythonParserWarning: Attempting to fix invalid location '159531..87293' as it looks like incorrect origin wrapping. Please fix input file, this could have unintended behavior.
#   BiopythonParserWarning,
# {'Sample': 'NC_039424.1', 'Nfeatures_raw': 461, 'Ngenes_raw': 121, 'Nfeatures_sel': 177, 'Ngenes_sel': 115, 'Nidentical': 0, 'Nduplicates': 36, 'Nfeatures': 115, 'Ngenes': 115}
# {'gene': 168, 'CDS': 96, 'exon': 72, 'tRNA': 71, 'intron': 39, 'rRNA': 10, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_039600.1', 'Nfeatures_raw': 475, 'Ngenes_raw': 119, 'Nfeatures_sel': 179, 'Ngenes_sel': 114, 'Nidentical': 0, 'Nduplicates': 40, 'Nfeatures': 114, 'Ngenes': 114}
# {'gene': 168, 'CDS': 101, 'exon': 79, 'tRNA': 67, 'intron': 44, 'rRNA': 11, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 31, 'rRNA': 4}
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\GenBank\__init__.py:366: BiopythonParserWarning: Attempting to fix invalid location '157771..87110' as it looks like incorrect origin wrapping. Please fix input file, this could have unintended behavior.
#   BiopythonParserWarning,
# {'Sample': 'NC_039627.1', 'Nfeatures_raw': 492, 'Ngenes_raw': 124, 'Nfeatures_sel': 182, 'Ngenes_sel': 116, 'Nidentical': 0, 'Nduplicates': 37, 'Nfeatures': 116, 'Ngenes': 116}
# {'gene': 176, 'CDS': 101, 'exon': 81, 'tRNA': 67, 'intron': 42, 'rRNA': 20, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 80, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_039676.1', 'Nfeatures_raw': 487, 'Ngenes_raw': 123, 'Nfeatures_sel': 185, 'Ngenes_sel': 115, 'Nidentical': 0, 'Nduplicates': 40, 'Nfeatures': 115, 'Ngenes': 115}
# {'gene': 176, 'CDS': 104, 'exon': 77, 'tRNA': 70, 'intron': 41, 'rRNA': 14, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_039731.1', 'Nfeatures_raw': 461, 'Ngenes_raw': 121, 'Nfeatures_sel': 173, 'Ngenes_sel': 115, 'Nidentical': 0, 'Nduplicates': 35, 'Nfeatures': 115, 'Ngenes': 115}
# {'gene': 161, 'CDS': 98, 'exon': 79, 'tRNA': 65, 'intron': 43, 'rRNA': 10, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 32, 'rRNA': 4}
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\GenBank\__init__.py:366: BiopythonParserWarning: Attempting to fix invalid location '160932..89144' as it looks like incorrect origin wrapping. Please fix input file, this could have unintended behavior.
#   BiopythonParserWarning,
# {'Sample': 'NC_039803.1', 'Nfeatures_raw': 455, 'Ngenes_raw': 122, 'Nfeatures_sel': 169, 'Ngenes_sel': 115, 'Nidentical': 0, 'Nduplicates': 33, 'Nfeatures': 115, 'Ngenes': 115}
# {'gene': 158, 'CDS': 95, 'exon': 79, 'tRNA': 65, 'intron': 43, 'rRNA': 10, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_039815.1', 'Nfeatures_raw': 489, 'Ngenes_raw': 123, 'Nfeatures_sel': 187, 'Ngenes_sel': 115, 'Nidentical': 0, 'Nduplicates': 41, 'Nfeatures': 115, 'Ngenes': 115}
# {'gene': 180, 'CDS': 105, 'exon': 74, 'tRNA': 71, 'intron': 40, 'rRNA': 14, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_040160.1', 'Nfeatures_raw': 369, 'Ngenes_raw': 117, 'Nfeatures_sel': 146, 'Ngenes_sel': 115, 'Nidentical': 0, 'Nduplicates': 25, 'Nfeatures': 115, 'Ngenes': 115}
# {'gene': 139, 'CDS': 89, 'exon': 54, 'tRNA': 52, 'intron': 29, 'rRNA': 5, 'source': 1}
# {'CDS': 79, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_040219.1', 'Nfeatures_raw': 502, 'Ngenes_raw': 122, 'Nfeatures_sel': 206, 'Ngenes_sel': 114, 'Nidentical': 0, 'Nduplicates': 52, 'Nfeatures': 114, 'Ngenes': 114}
# {'gene': 206, 'CDS': 137, 'tRNA': 58, 'exon': 47, 'intron': 30, 'rRNA': 19, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 84, 'tRNA': 26, 'rRNA': 4}
# {'Sample': 'NC_040862.1', 'Nfeatures_raw': 401, 'Ngenes_raw': 99, 'Nfeatures_sel': 158, 'Ngenes_sel': 96, 'Nidentical': 0, 'Nduplicates': 37, 'Nfeatures': 96, 'Ngenes': 96}
# {'gene': 154, 'CDS': 80, 'tRNA': 64, 'exon': 52, 'intron': 34, 'rRNA': 16, 'source': 1}
# {'CDS': 64, 'tRNA': 28, 'rRNA': 4}
# {'Sample': 'NC_040983.1', 'Nfeatures_raw': 478, 'Ngenes_raw': 119, 'Nfeatures_sel': 180, 'Ngenes_sel': 113, 'Nidentical': 0, 'Nduplicates': 38, 'Nfeatures': 113, 'Ngenes': 113}
# {'gene': 171, 'CDS': 103, 'exon': 79, 'tRNA': 68, 'intron': 42, 'rRNA': 10, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 78, 'tRNA': 31, 'rRNA': 4}
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\GenBank\__init__.py:366: BiopythonParserWarning: Attempting to fix invalid location '136363..5491' as it looks like incorrect origin wrapping. Please fix input file, this could have unintended behavior.
#   BiopythonParserWarning,
# {'Sample': 'NC_041000.1', 'Nfeatures_raw': 539, 'Ngenes_raw': 127, 'Nfeatures_sel': 205, 'Ngenes_sel': 119, 'Nidentical': 0, 'Nduplicates': 48, 'Nfeatures': 119, 'Ngenes': 119}
# {'gene': 207, 'CDS': 135, 'exon': 70, 'tRNA': 57, 'intron': 45, 'rRNA': 20, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 85, 'tRNA': 30, 'rRNA': 4}
# {'Sample': 'NC_041127.1', 'Nfeatures_raw': 444, 'Ngenes_raw': 123, 'Nfeatures_sel': 168, 'Ngenes_sel': 116, 'Nidentical': 0, 'Nduplicates': 32, 'Nfeatures': 116, 'Ngenes': 116}
# {'gene': 158, 'CDS': 95, 'exon': 73, 'tRNA': 64, 'intron': 39, 'rRNA': 10, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 80, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_041261.1', 'Nfeatures_raw': 520, 'Ngenes_raw': 124, 'Nfeatures_sel': 191, 'Ngenes_sel': 115, 'Nidentical': 0, 'Nduplicates': 35, 'Nfeatures': 115, 'Ngenes': 115}
# {'gene': 188, 'CDS': 109, 'exon': 84, 'tRNA': 67, 'intron': 45, 'rRNA': 22, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_041275.1', 'Nfeatures_raw': 455, 'Ngenes_raw': 122, 'Nfeatures_sel': 172, 'Ngenes_sel': 115, 'Nidentical': 0, 'Nduplicates': 35, 'Nfeatures': 115, 'Ngenes': 115}
# {'gene': 161, 'CDS': 99, 'exon': 75, 'tRNA': 64, 'intron': 41, 'rRNA': 10, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_041281.1', 'Nfeatures_raw': 451, 'Ngenes_raw': 121, 'Nfeatures_sel': 169, 'Ngenes_sel': 115, 'Nidentical': 0, 'Nduplicates': 33, 'Nfeatures': 115, 'Ngenes': 115}
# {'gene': 157, 'CDS': 95, 'exon': 78, 'tRNA': 64, 'intron': 42, 'rRNA': 10, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_041452.1', 'Nfeatures_raw': 484, 'Ngenes_raw': 121, 'Nfeatures_sel': 180, 'Ngenes_sel': 115, 'Nidentical': 0, 'Nduplicates': 36, 'Nfeatures': 115, 'Ngenes': 115}
# {'gene': 170, 'CDS': 97, 'exon': 83, 'tRNA': 71, 'intron': 44, 'rRNA': 14, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_041466.1', 'Nfeatures_raw': 394, 'Ngenes_raw': 123, 'Nfeatures_sel': 159, 'Ngenes_sel': 119, 'Nidentical': 0, 'Nduplicates': 31, 'Nfeatures': 119, 'Ngenes': 119}
# {'gene': 161, 'CDS': 102, 'tRNA': 48, 'exon': 43, 'intron': 26, 'rRNA': 13, 'source': 1}
# {'CDS': 83, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_041475.1', 'Nfeatures_raw': 451, 'Ngenes_raw': 123, 'Nfeatures_sel': 168, 'Ngenes_sel': 116, 'Nidentical': 0, 'Nduplicates': 31, 'Nfeatures': 116, 'Ngenes': 116}
# {'gene': 158, 'CDS': 95, 'exon': 78, 'tRNA': 64, 'intron': 41, 'rRNA': 10, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 33, 'rRNA': 4}
# {'Sample': 'NC_041481.1', 'Nfeatures_raw': 450, 'Ngenes_raw': 120, 'Nfeatures_sel': 171, 'Ngenes_sel': 114, 'Nidentical': 0, 'Nduplicates': 34, 'Nfeatures': 114, 'Ngenes': 114}
# {'gene': 162, 'CDS': 96, 'exon': 71, 'tRNA': 63, 'intron': 39, 'rRNA': 14, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 31, 'rRNA': 4}
# {'Sample': 'NC_041492.1', 'Nfeatures_raw': 464, 'Ngenes_raw': 121, 'Nfeatures_sel': 173, 'Ngenes_sel': 115, 'Nidentical': 0, 'Nduplicates': 36, 'Nfeatures': 115, 'Ngenes': 115}
# {'gene': 162, 'CDS': 96, 'exon': 80, 'tRNA': 67, 'intron': 44, 'rRNA': 10, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_041640.1', 'Nfeatures_raw': 403, 'Ngenes_raw': 98, 'Nfeatures_sel': 180, 'Ngenes_sel': 95, 'Nidentical': 0, 'Nduplicates': 55, 'Nfeatures': 95, 'Ngenes': 95}
# {'gene': 184, 'CDS': 139, 'tRNA': 23, 'exon': 22, 'rRNA': 22, 'intron': 12, 'source': 1}
# {'CDS': 79, 'tRNA': 12, 'rRNA': 4}
# {'Sample': 'NC_042211.1', 'Nfeatures_raw': 442, 'Ngenes_raw': 121, 'Nfeatures_sel': 169, 'Ngenes_sel': 112, 'Nidentical': 0, 'Nduplicates': 32, 'Nfeatures': 112, 'Ngenes': 112}
# {'gene': 164, 'CDS': 89, 'tRNA': 69, 'exon': 66, 'intron': 35, 'rRNA': 14, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 77, 'tRNA': 31, 'rRNA': 4}
# {'Sample': 'NC_042450.1', 'Nfeatures_raw': 458, 'Ngenes_raw': 122, 'Nfeatures_sel': 171, 'Ngenes_sel': 115, 'Nidentical': 0, 'Nduplicates': 33, 'Nfeatures': 115, 'Ngenes': 115}
# {'gene': 162, 'CDS': 95, 'exon': 77, 'tRNA': 64, 'intron': 41, 'rRNA': 14, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_042597.1', 'Nfeatures_raw': 448, 'Ngenes_raw': 116, 'Nfeatures_sel': 167, 'Ngenes_sel': 108, 'Nidentical': 0, 'Nduplicates': 32, 'Nfeatures': 108, 'Ngenes': 108}
# {'gene': 159, 'CDS': 93, 'exon': 76, 'tRNA': 66, 'intron': 39, 'rRNA': 10, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 72, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_042740.1', 'Nfeatures_raw': 462, 'Ngenes_raw': 123, 'Nfeatures_sel': 171, 'Ngenes_sel': 114, 'Nidentical': 0, 'Nduplicates': 35, 'Nfeatures': 114, 'Ngenes': 114}
# {'gene': 165, 'CDS': 99, 'exon': 76, 'tRNA': 63, 'intron': 41, 'rRNA': 13, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 31, 'rRNA': 4}
# {'Sample': 'NC_042889.1', 'Nfeatures_raw': 466, 'Ngenes_raw': 121, 'Nfeatures_sel': 182, 'Ngenes_sel': 115, 'Nidentical': 0, 'Nduplicates': 42, 'Nfeatures': 115, 'Ngenes': 115}
# {'gene': 173, 'CDS': 103, 'exon': 68, 'tRNA': 65, 'intron': 36, 'rRNA': 16, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 32, 'rRNA': 4}
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\GenBank\__init__.py:366: BiopythonParserWarning: Attempting to fix invalid location '160919..88145' as it looks like incorrect origin wrapping. Please fix input file, this could have unintended behavior.
#   BiopythonParserWarning,
# {'Sample': 'NC_042940.1', 'Nfeatures_raw': 510, 'Ngenes_raw': 122, 'Nfeatures_sel': 192, 'Ngenes_sel': 115, 'Nidentical': 0, 'Nduplicates': 42, 'Nfeatures': 115, 'Ngenes': 115}
# {'gene': 181, 'CDS': 111, 'exon': 83, 'tRNA': 68, 'intron': 48, 'rRNA': 14, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_043796.1', 'Nfeatures_raw': 487, 'Ngenes_raw': 124, 'Nfeatures_sel': 183, 'Ngenes_sel': 115, 'Nidentical': 0, 'Nduplicates': 35, 'Nfeatures': 115, 'Ngenes': 115}
# {'gene': 175, 'CDS': 107, 'exon': 77, 'tRNA': 64, 'intron': 43, 'rRNA': 16, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 78, 'tRNA': 33, 'rRNA': 4}
# {'Sample': 'NC_043800.1', 'Nfeatures_raw': 464, 'Ngenes_raw': 122, 'Nfeatures_sel': 174, 'Ngenes_sel': 115, 'Nidentical': 0, 'Nduplicates': 32, 'Nfeatures': 115, 'Ngenes': 115}
# {'gene': 165, 'CDS': 96, 'exon': 77, 'tRNA': 66, 'intron': 41, 'rRNA': 14, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_043867.1', 'Nfeatures_raw': 479, 'Ngenes_raw': 124, 'Nfeatures_sel': 181, 'Ngenes_sel': 117, 'Nidentical': 0, 'Nduplicates': 35, 'Nfeatures': 117, 'Ngenes': 117}
# {'gene': 172, 'CDS': 104, 'exon': 76, 'tRNA': 65, 'intron': 41, 'rRNA': 16, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 81, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_044728.1', 'Nfeatures_raw': 447, 'Ngenes_raw': 122, 'Nfeatures_sel': 169, 'Ngenes_sel': 116, 'Nidentical': 0, 'Nduplicates': 35, 'Nfeatures': 116, 'Ngenes': 116}
# {'gene': 159, 'CDS': 95, 'exon': 73, 'tRNA': 64, 'intron': 41, 'rRNA': 10, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 33, 'rRNA': 4}
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\GenBank\__init__.py:366: BiopythonParserWarning: Attempting to fix invalid location '156852..86364' as it looks like incorrect origin wrapping. Please fix input file, this could have unintended behavior.
#   BiopythonParserWarning,
# {'Sample': 'NC_044826.1', 'Nfeatures_raw': 461, 'Ngenes_raw': 121, 'Nfeatures_sel': 173, 'Ngenes_sel': 115, 'Nidentical': 0, 'Nduplicates': 35, 'Nfeatures': 115, 'Ngenes': 115}
# {'gene': 161, 'CDS': 98, 'exon': 79, 'tRNA': 65, 'intron': 43, 'rRNA': 10, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_044828.1', 'Nfeatures_raw': 459, 'Ngenes_raw': 123, 'Nfeatures_sel': 172, 'Ngenes_sel': 116, 'Nidentical': 0, 'Nduplicates': 33, 'Nfeatures': 116, 'Ngenes': 116}
# {'gene': 161, 'CDS': 97, 'exon': 78, 'tRNA': 66, 'intron': 42, 'rRNA': 10, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 80, 'tRNA': 32, 'rRNA': 4}
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\GenBank\__init__.py:366: BiopythonParserWarning: Attempting to fix invalid location '158724..86383' as it looks like incorrect origin wrapping. Please fix input file, this could have unintended behavior.
#   BiopythonParserWarning,
# {'Sample': 'NC_045081.1', 'Nfeatures_raw': 469, 'Ngenes_raw': 121, 'Nfeatures_sel': 182, 'Ngenes_sel': 115, 'Nidentical': 0, 'Nduplicates': 41, 'Nfeatures': 115, 'Ngenes': 115}
# {'gene': 174, 'CDS': 101, 'tRNA': 71, 'exon': 70, 'intron': 38, 'rRNA': 10, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_045235.1', 'Nfeatures_raw': 466, 'Ngenes_raw': 119, 'Nfeatures_sel': 176, 'Ngenes_sel': 112, 'Nidentical': 0, 'Nduplicates': 42, 'Nfeatures': 112, 'Ngenes': 112}
# {'gene': 164, 'CDS': 103, 'exon': 77, 'tRNA': 65, 'intron': 42, 'rRNA': 10, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 77, 'tRNA': 31, 'rRNA': 4}
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\GenBank\__init__.py:366: BiopythonParserWarning: Attempting to fix invalid location '157850..87258' as it looks like incorrect origin wrapping. Please fix input file, this could have unintended behavior.
#   BiopythonParserWarning,
# {'Sample': 'NC_045274.1', 'Nfeatures_raw': 462, 'Ngenes_raw': 121, 'Nfeatures_sel': 173, 'Ngenes_sel': 115, 'Nidentical': 0, 'Nduplicates': 36, 'Nfeatures': 115, 'Ngenes': 115}
# {'gene': 163, 'CDS': 95, 'exon': 78, 'tRNA': 68, 'intron': 43, 'rRNA': 10, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_045280.1', 'Nfeatures_raw': 484, 'Ngenes_raw': 120, 'Nfeatures_sel': 184, 'Ngenes_sel': 113, 'Nidentical': 0, 'Nduplicates': 39, 'Nfeatures': 113, 'Ngenes': 113}
# {'gene': 177, 'CDS': 103, 'exon': 74, 'tRNA': 69, 'intron': 42, 'rRNA': 14, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 77, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_045294.1', 'Nfeatures_raw': 497, 'Ngenes_raw': 124, 'Nfeatures_sel': 186, 'Ngenes_sel': 115, 'Nidentical': 0, 'Nduplicates': 38, 'Nfeatures': 115, 'Ngenes': 115}
# {'gene': 179, 'CDS': 104, 'exon': 80, 'tRNA': 69, 'intron': 42, 'rRNA': 18, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_045400.1', 'Nfeatures_raw': 459, 'Ngenes_raw': 119, 'Nfeatures_sel': 177, 'Ngenes_sel': 114, 'Nidentical': 0, 'Nduplicates': 38, 'Nfeatures': 114, 'Ngenes': 114}
# {'gene': 168, 'CDS': 100, 'exon': 69, 'tRNA': 67, 'intron': 40, 'rRNA': 10, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 31, 'rRNA': 4}
# {'Sample': 'NC_046385.1', 'Nfeatures_raw': 465, 'Ngenes_raw': 119, 'Nfeatures_sel': 176, 'Ngenes_sel': 113, 'Nidentical': 0, 'Nduplicates': 41, 'Nfeatures': 113, 'Ngenes': 113}
# {'gene': 166, 'CDS': 99, 'exon': 77, 'tRNA': 67, 'intron': 41, 'rRNA': 10, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 30, 'rRNA': 4}
# {'Sample': 'NC_046458.1', 'Nfeatures_raw': 478, 'Ngenes_raw': 121, 'Nfeatures_sel': 184, 'Ngenes_sel': 115, 'Nidentical': 0, 'Nduplicates': 39, 'Nfeatures': 115, 'Ngenes': 115}
# {'gene': 175, 'CDS': 106, 'exon': 74, 'tRNA': 68, 'intron': 40, 'rRNA': 10, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_046575.1', 'Nfeatures_raw': 457, 'Ngenes_raw': 123, 'Nfeatures_sel': 174, 'Ngenes_sel': 115, 'Nidentical': 0, 'Nduplicates': 36, 'Nfeatures': 115, 'Ngenes': 115}
# {'gene': 167, 'CDS': 98, 'exon': 70, 'tRNA': 65, 'intron': 38, 'rRNA': 14, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_046602.1', 'Nfeatures_raw': 467, 'Ngenes_raw': 120, 'Nfeatures_sel': 181, 'Ngenes_sel': 114, 'Nidentical': 0, 'Nduplicates': 40, 'Nfeatures': 114, 'Ngenes': 114}
# {'gene': 174, 'CDS': 103, 'exon': 69, 'tRNA': 66, 'intron': 36, 'rRNA': 14, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 31, 'rRNA': 4}
# {'Sample': 'NC_048982.1', 'Nfeatures_raw': 460, 'Ngenes_raw': 119, 'Nfeatures_sel': 173, 'Ngenes_sel': 114, 'Nidentical': 0, 'Nduplicates': 37, 'Nfeatures': 114, 'Ngenes': 114}
# {'gene': 162, 'CDS': 98, 'exon': 78, 'tRNA': 65, 'intron': 42, 'rRNA': 10, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 31, 'rRNA': 4}
# {'Sample': 'NC_049157.1', 'Nfeatures_raw': 453, 'Ngenes_raw': 121, 'Nfeatures_sel': 169, 'Ngenes_sel': 115, 'Nidentical': 0, 'Nduplicates': 31, 'Nfeatures': 115, 'Ngenes': 115}
# {'gene': 157, 'CDS': 94, 'exon': 79, 'tRNA': 65, 'intron': 43, 'rRNA': 10, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_049578.1', 'Nfeatures_raw': 469, 'Ngenes_raw': 120, 'Nfeatures_sel': 174, 'Ngenes_sel': 114, 'Nidentical': 0, 'Nduplicates': 38, 'Nfeatures': 114, 'Ngenes': 114}
# {'gene': 165, 'CDS': 95, 'exon': 81, 'tRNA': 70, 'intron': 43, 'rRNA': 10, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 31, 'rRNA': 4}
# {'Sample': 'NC_050211.1', 'Nfeatures_raw': 475, 'Ngenes_raw': 123, 'Nfeatures_sel': 177, 'Ngenes_sel': 116, 'Nidentical': 0, 'Nduplicates': 34, 'Nfeatures': 116, 'Ngenes': 116}
# {'gene': 169, 'CDS': 99, 'exon': 78, 'tRNA': 66, 'intron': 42, 'rRNA': 16, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 80, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_050270.1', 'Nfeatures_raw': 443, 'Ngenes_raw': 121, 'Nfeatures_sel': 168, 'Ngenes_sel': 115, 'Nidentical': 0, 'Nduplicates': 33, 'Nfeatures': 115, 'Ngenes': 115}
# {'gene': 157, 'CDS': 93, 'exon': 74, 'tRNA': 65, 'intron': 39, 'rRNA': 10, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_050853.1', 'Nfeatures_raw': 463, 'Ngenes_raw': 123, 'Nfeatures_sel': 172, 'Ngenes_sel': 115, 'Nidentical': 0, 'Nduplicates': 33, 'Nfeatures': 115, 'Ngenes': 115}
# {'gene': 162, 'CDS': 98, 'exon': 79, 'tRNA': 66, 'intron': 43, 'rRNA': 10, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_050922.1', 'Nfeatures_raw': 434, 'Ngenes_raw': 122, 'Nfeatures_sel': 166, 'Ngenes_sel': 115, 'Nidentical': 0, 'Nduplicates': 35, 'Nfeatures': 115, 'Ngenes': 115}
# {'gene': 159, 'CDS': 94, 'exon': 66, 'tRNA': 63, 'intron': 37, 'rRNA': 10, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_050986.1', 'Nfeatures_raw': 476, 'Ngenes_raw': 121, 'Nfeatures_sel': 181, 'Ngenes_sel': 115, 'Nidentical': 0, 'Nduplicates': 34, 'Nfeatures': 115, 'Ngenes': 115}
# {'gene': 173, 'CDS': 102, 'exon': 75, 'tRNA': 67, 'intron': 40, 'rRNA': 14, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 80, 'tRNA': 31, 'rRNA': 4}
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\GenBank\__init__.py:366: BiopythonParserWarning: Attempting to fix invalid location '158598..0' as it looks like incorrect origin wrapping. Please fix input file, this could have unintended behavior.
#   BiopythonParserWarning,
# {'Sample': 'NC_051913.1', 'Nfeatures_raw': 471, 'Ngenes_raw': 123, 'Nfeatures_sel': 171, 'Ngenes_sel': 115, 'Nidentical': 0, 'Nduplicates': 33, 'Nfeatures': 115, 'Ngenes': 115}
# {'gene': 165, 'CDS': 97, 'exon': 80, 'tRNA': 63, 'intron': 45, 'rRNA': 16, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_051971.1', 'Nfeatures_raw': 470, 'Ngenes_raw': 120, 'Nfeatures_sel': 177, 'Ngenes_sel': 114, 'Nidentical': 0, 'Nduplicates': 37, 'Nfeatures': 114, 'Ngenes': 114}
# {'gene': 166, 'CDS': 97, 'exon': 79, 'tRNA': 68, 'intron': 43, 'rRNA': 12, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 78, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_051978.1', 'Nfeatures_raw': 518, 'Ngenes_raw': 129, 'Nfeatures_sel': 194, 'Ngenes_sel': 122, 'Nidentical': 0, 'Nduplicates': 46, 'Nfeatures': 122, 'Ngenes': 122}
# {'gene': 193, 'CDS': 114, 'exon': 74, 'tRNA': 66, 'intron': 46, 'rRNA': 20, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 85, 'tRNA': 33, 'rRNA': 4}
# {'Sample': 'NC_052855.1', 'Nfeatures_raw': 466, 'Ngenes_raw': 117, 'Nfeatures_sel': 181, 'Ngenes_sel': 115, 'Nidentical': 0, 'Nduplicates': 43, 'Nfeatures': 115, 'Ngenes': 115}
# {'gene': 173, 'CDS': 106, 'exon': 72, 'tRNA': 65, 'intron': 39, 'rRNA': 10, 'source': 1}
# {'CDS': 79, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_052912.1', 'Nfeatures_raw': 461, 'Ngenes_raw': 120, 'Nfeatures_sel': 177, 'Ngenes_sel': 113, 'Nidentical': 0, 'Nduplicates': 37, 'Nfeatures': 113, 'Ngenes': 113}
# {'gene': 170, 'CDS': 100, 'exon': 68, 'tRNA': 66, 'intron': 38, 'rRNA': 14, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 77, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_052922.1', 'Nfeatures_raw': 460, 'Ngenes_raw': 120, 'Nfeatures_sel': 173, 'Ngenes_sel': 114, 'Nidentical': 0, 'Nduplicates': 33, 'Nfeatures': 114, 'Ngenes': 114}
# {'gene': 162, 'CDS': 101, 'exon': 78, 'tRNA': 63, 'intron': 41, 'rRNA': 10, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 31, 'rRNA': 4}
# {'Sample': 'NC_053567.1', 'Nfeatures_raw': 489, 'Ngenes_raw': 128, 'Nfeatures_sel': 188, 'Ngenes_sel': 123, 'Nidentical': 0, 'Nduplicates': 39, 'Nfeatures': 123, 'Ngenes': 123}
# {'gene': 179, 'CDS': 108, 'exon': 76, 'tRNA': 68, 'intron': 41, 'rRNA': 12, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 86, 'tRNA': 33, 'rRNA': 4}
# {'Sample': 'NC_053620.1', 'Nfeatures_raw': 458, 'Ngenes_raw': 122, 'Nfeatures_sel': 172, 'Ngenes_sel': 115, 'Nidentical': 0, 'Nduplicates': 34, 'Nfeatures': 115, 'Ngenes': 115}
# {'gene': 162, 'CDS': 95, 'exon': 77, 'tRNA': 65, 'intron': 40, 'rRNA': 14, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_053780.1', 'Nfeatures_raw': 447, 'Ngenes_raw': 119, 'Nfeatures_sel': 167, 'Ngenes_sel': 113, 'Nidentical': 0, 'Nduplicates': 35, 'Nfeatures': 113, 'Ngenes': 113}
# {'gene': 162, 'CDS': 90, 'exon': 70, 'tRNA': 65, 'intron': 39, 'rRNA': 16, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 78, 'tRNA': 31, 'rRNA': 4}
# {'Sample': 'NC_053784.1', 'Nfeatures_raw': 467, 'Ngenes_raw': 121, 'Nfeatures_sel': 178, 'Ngenes_sel': 115, 'Nidentical': 0, 'Nduplicates': 38, 'Nfeatures': 115, 'Ngenes': 115}
# {'gene': 168, 'CDS': 97, 'exon': 76, 'tRNA': 71, 'intron': 40, 'rRNA': 10, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 32, 'rRNA': 4}
# {'Sample': 'NC_053912.1', 'Nfeatures_raw': 453, 'Ngenes_raw': 120, 'Nfeatures_sel': 170, 'Ngenes_sel': 114, 'Nidentical': 0, 'Nduplicates': 33, 'Nfeatures': 114, 'Ngenes': 114}
# {'gene': 161, 'CDS': 94, 'exon': 75, 'tRNA': 67, 'intron': 41, 'rRNA': 10, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 31, 'rRNA': 4}
# {'Sample': 'NC_054296.1', 'Nfeatures_raw': 457, 'Ngenes_raw': 120, 'Nfeatures_sel': 171, 'Ngenes_sel': 114, 'Nidentical': 0, 'Nduplicates': 33, 'Nfeatures': 114, 'Ngenes': 114}
# {'gene': 162, 'CDS': 96, 'exon': 77, 'tRNA': 65, 'intron': 41, 'rRNA': 11, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 31, 'rRNA': 4}
# {'Sample': 'NC_054306.1', 'Nfeatures_raw': 490, 'Ngenes_raw': 121, 'Nfeatures_sel': 181, 'Ngenes_sel': 114, 'Nidentical': 0, 'Nduplicates': 38, 'Nfeatures': 114, 'Ngenes': 114}
# {'gene': 171, 'CDS': 102, 'exon': 84, 'tRNA': 68, 'intron': 46, 'rRNA': 14, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 79, 'tRNA': 31, 'rRNA': 4}
# {'Sample': 'NC_054357.1', 'Nfeatures_raw': 436, 'Ngenes_raw': 108, 'Nfeatures_sel': 168, 'Ngenes_sel': 101, 'Nidentical': 0, 'Nduplicates': 39, 'Nfeatures': 101, 'Ngenes': 101}
# {'gene': 173, 'CDS': 97, 'tRNA': 59, 'exon': 51, 'intron': 30, 'rRNA': 21, 'misc_feature': 2, 'repeat_region': 2, 'source': 1}
# {'CDS': 68, 'tRNA': 29, 'rRNA': 4}
# {'Sample': 'NC_054359.1', 'Nfeatures_raw': 445, 'Ngenes_raw': 116, 'Nfeatures_sel': 168, 'Ngenes_sel': 114, 'Nidentical': 0, 'Nduplicates': 34, 'Nfeatures': 114, 'Ngenes': 114}
# {'gene': 158, 'CDS': 92, 'exon': 76, 'tRNA': 66, 'intron': 42, 'rRNA': 10, 'source': 1}
# {'CDS': 79, 'tRNA': 31, 'rRNA': 4}

# %%
Samples_stats = pd.DataFrame(Samples_ls)
Samples_stats.to_csv(ref_dir + 'Ref_stats.csv',index=False)
print('Ngenes:',Samples_stats.Ngenes.quantile([.1,.5,.9]).astype(int).to_dict())
print('Nduplicates:',Samples_stats.Nduplicates.quantile([.1,.5,.9]).astype(int).to_dict())
Samples_stats
# Out:
# Ngenes: {0.1: 113, 0.5: 115, 0.9: 119}
# Nduplicates: {0.1: 32, 0.5: 36, 0.9: 47}
#           Sample  Nfeatures_raw  Ngenes_raw  Nfeatures_sel  Ngenes_sel  \
# 0    NC_003386.1            546         129            208         119
# 1    NC_005086.1            467         120            177         115
# 2    NC_009962.1            448         119            169         114
# 3    NC_010323.1            455         121            170         115
# 4    NC_010654.1            390         103            148          96
# ..           ...            ...         ...            ...         ...
# 119  NC_053912.1            453         120            170         114
# 120  NC_054296.1            457         120            171         114
# 121  NC_054306.1            490         121            181         114
# 122  NC_054357.1            436         108            168         101
# 123  NC_054359.1            445         116            168         114
#
#      Nidentical  Nduplicates  Nfeatures  Ngenes
# 0             0           49        119     119
# 1             0           38        115     115
# 2             0           32        114     114
# 3             0           32        115     115
# 4             0           25         96      96
# ..          ...          ...        ...     ...
# 119           0           33        114     114
# 120           0           33        114     114
# 121           0           38        114     114
# 122           0           39        101     101
# 123           0           34        114     114
#
# [124 rows x 9 columns]

# %%
# Concat .fasta files in a single fasta
all_fa_files = [file for file in os.listdir(ref_dir) if file.endswith("_CDS.fasta")]
print(len(all_fa_files))
all_seqs=[]; ls_id=[]
for ifa in all_fa_files:
    for record in SeqIO.parse(ref_dir + ifa,format='fasta'):
        all_seqs.append(record)
SeqIO.write(all_seqs,ref_dir + 'cpDNA_RefCDS_raw.fasta',format='fasta')
len(all_seqs)
# Out:
# 124
# 14213

# %%
# https://blog.finxter.com/how-to-extract-numbers-from-a-string-in-python/
import re
def get_loc(sentence):
    return [float(s) for s in re.findall(r'-?\d+\.?\d*', sentence)]
print(get_loc('join{[126649:127202](-), [125052:125582](-)}	'))

ls_loc=[76120.0, 76234.0, 105286.0, 105518.0, 104729.0, 104829.0]
def len_exons(ls_loc):
    len_exon=0;
    for i in range(0,len(ls_loc),2):
        exon = ls_loc[i:i+2]
        len_exon += max(exon) - min(exon)
    return len_exon
def len_introns(ls_loc):
    len_intron=0;
    if len(ls_loc)/4>0:
        for i in range(1,len(ls_loc),4):
            intron = ls_loc[i:i+2]
            len_intron += max(intron) - min(intron)
    return len_intron
print(len_exons(ls_loc),len_introns(ls_loc))
# Out:
# [126649.0, 127202.0, 125052.0, 125582.0]
# 446.0 29052.0

# %%
ref_stats={}
for record in all_seqs:
    location = record.description.split('location=')[1].split(';')[0]
    ref_stats[record.id]={'len':len(record),'join':'join' in location,'forward':'+' in location,'reverse':'-' in location,
                         'location':location}
ref_stats = pd.DataFrame.from_dict(ref_stats,orient='index').reset_index().rename(columns={'index':'seqid'})
ref_stats[['Accession','gene']]=ref_stats.seqid.str.split('-',expand=True)
ref_stats['ls_loc'] = ref_stats.apply(lambda row: get_loc(row['location']),axis=1)
ref_stats['N_exons'] = ref_stats.apply(lambda row: len(row['ls_loc'])/2,axis=1)
ref_stats['len_exons'] = ref_stats.apply(lambda row: len_exons(row['ls_loc']),axis=1)
ref_stats['len_introns'] = ref_stats.apply(lambda row: len_introns(row['ls_loc']),axis=1)
ref_stats[:2]
# Out:
#               seqid   len   join  forward  reverse          location  \
# 0  NC_003386.1-accD   929  False     True    False  [57912:58841](+)
# 1  NC_003386.1-atpA  1527  False    False     True  [15691:17218](-)
#
#      Accession  gene              ls_loc  N_exons  len_exons  len_introns
# 0  NC_003386.1  accD  [57912.0, 58841.0]      1.0      929.0          0.0
# 1  NC_003386.1  atpA  [15691.0, 17218.0]      1.0     1527.0          0.0

# %%
gene_stats = ref_stats.groupby('gene').agg({'len':['min','median','max'],'Accession':['count'],'forward':['sum'],
                            'reverse':['sum'],'join':['sum'],'N_exons':['mean'],'len_exons':['median'],'len_introns':['median','max']})
gene_stats.columns = ['_'.join(col).strip() for col in gene_stats.columns.values]
gene_stats.reset_index().to_csv(ref_dir + 'gene_stats.csv',index=False)
gene_stats[gene_stats.join_sum>5]
# Out:
#           len_min  len_median  len_max  Accession_count  forward_sum  \
# gene
# atpF          424       555.0      576              124           13
# clpP1         273       591.0      948              121           10
# ndhA          301      1092.0     1119              116           23
# ndhB          311      1533.0     1569              119           46
# pafI          228       507.0      543              124           11
# petB          489       648.0      708              124          116
# petD          479       483.0      539              124          116
# rpl16           9       408.0      492              124            8
# rpl2          392       825.0      849              123           57
# rpoC1        1359      2049.0     2118              124           14
# rps12         232       372.0      806              124           81
# rps16          40       261.0      534              111            5
# trnA_UGC       35       105.0      435              123           58
# trnC_ACA       72        95.0       97               59            3
# trnE_UUC       73        75.0       80              124           17
# trnF_AAA       80        93.0       93                7            1
# trnG_UCC       23        71.0       92              119          108
# trnI_AAU       73        91.5       92               10            4
# trnI_GAU       72        88.0      295              121           58
# trnK_UUU       37        72.0       90              115            6
# trnL_UAA       34        85.0      472              123          112
# trnS_CGA       70        92.0       94               84           75
# trnT_CGU       77        78.0       91               23           21
# trnV_UAC       37        74.0      285              118           10
#
#           reverse_sum  join_sum  N_exons_mean  len_exons_median  \
# gene
# atpF              111       123      1.991935             555.0
# clpP1             111       106      2.727273             591.0
# ndhA               93       113      1.974138            1092.0
# ndhB               73       114      1.957983            1533.0
# pafI              113       121      2.943548             507.0
# petB                8       113      1.911290             648.0
# petD                8        90      1.725806             483.0
# rpl16             116       102      1.822581             408.0
# rpl2               66       117      1.959350             825.0
# rpoC1             110       118      1.951613            2049.0
# rps12             115       119      2.887097             372.0
# rps16             106        90      1.810811             261.0
# trnA_UGC           65        14      1.113821             105.0
# trnC_ACA           56        57      1.966102              95.0
# trnE_UUC          107        10      1.080645              75.0
# trnF_AAA            6         6      1.857143              93.0
# trnG_UCC           11       116      1.974790              71.0
# trnI_AAU            6         9      1.900000              91.5
# trnI_GAU           63        35      1.289256              88.0
# trnK_UUU          109       112      1.973913              72.0
# trnL_UAA           11       112      1.910569              85.0
# trnS_CGA            9        77      1.916667              92.0
# trnT_CGU            2        22      1.956522              78.0
# trnV_UAC          108       104      1.881356              74.0
#
#           len_introns_median  len_introns_max
# gene
# atpF                  1279.5           2338.0
# clpP1                 1160.0           1954.0
# ndhA                  2154.0           2553.0
# ndhB                  2203.0           2295.0
# pafI                  1081.0           1907.0
# petB                   781.5           1469.0
# petD                   716.0           1226.0
# rpl16                 1406.0           2195.0
# rpl2                  1285.0         158597.0
# rpoC1                 2795.0           3127.0
# rps12                69194.5         135516.0
# rps16                 1104.0           1822.0
# trnA_UGC                 0.0            885.0
# trnC_ACA               663.0            776.0
# trnE_UUC                 0.0           1044.0
# trnF_AAA               657.0            688.0
# trnG_UCC               723.0            954.0
# trnI_AAU               631.0            725.0
# trnI_GAU                 0.0           1141.0
# trnK_UUU              2582.0           4056.0
# trnL_UAA               510.0           1300.0
# trnS_CGA               698.0            933.0
# trnT_CGU               718.0            932.0
# trnV_UAC               659.0            775.0

# %%
print(gene_stats.shape[0],gene_stats.Accession_count.sort_values(ascending=False).to_dict())
# Out:
# 144 {'rpoC2': 124, 'rps12': 124, 'atpA': 124, 'rpoC1': 124, 'rpoB': 124, 'rpoA': 124, 'rpl36': 124, 'rpl33': 124, 'rpl20': 124, 'rpl16': 124, 'rpl14': 124, 'rbcL': 124, 'psbZ': 124, 'psbT': 124, 'psbM': 124, 'psbL': 124, 'psbK': 124, 'psbI': 124, 'psbH': 124, 'psbF': 124, 'psbE': 124, 'rps11': 124, 'rps14': 124, 'psbC': 124, 'rps18': 124, 'trnY_GUA': 124, 'trnW_CCA': 124, 'trnR_ACG': 124, 'trnQ_UUG': 124, 'trnM_CAU': 124, 'trnH_GUG': 124, 'trnE_UUC': 124, 'trnD_GUC': 124, 'trnC_GCA': 124, 'rrn5': 124, 'rrn4.5': 124, 'rrn23': 124, 'rrn16': 124, 'rps8': 124, 'rps7': 124, 'rps4': 124, 'rps3': 124, 'rps2': 124, 'rps19': 124, 'psbD': 124, 'ycf2': 124, 'psbB': 124, 'petG': 124, 'ccsA': 124, 'atpI': 124, 'pafI': 124, 'pafII': 124, 'pbf1': 124, 'atpH': 124, 'atpF': 124, 'petA': 124, 'petB': 124, 'petD': 124, 'psbA': 124, 'psaA': 124, 'psaB': 124, 'psaC': 124, 'atpB': 124, 'petN': 124, 'psaI': 124, 'psaJ': 124, 'atpE': 124, 'trnS_GCU': 123, 'trnL_UAG': 123, 'trnF_GAA': 123, 'trnL_UAA': 123, 'trnS_UGA': 123, 'trnN_GUU': 123, 'trnP_UGG': 123, 'trnA_UGC': 123, 'trnR_UCU': 123, 'cemA': 123, 'psbJ': 123, 'rpl22': 123, 'rpl2': 123, 'petL': 123, 'trnS_GGA': 122, 'matK': 122, 'ycf1': 122, 'trnI_GAU': 121, 'rpl23': 121, 'trnG_GCC': 121, 'trnL_CAA': 121, 'clpP1': 121, 'rps15': 120, 'trnT_GGU': 119, 'ndhD': 119, 'ndhB': 119, 'trnG_UCC': 119, 'accD': 118, 'trnV_UAC': 118, 'infA': 118, 'ndhC': 117, 'ndhE': 117, 'ndhG': 117, 'ndhK': 116, 'trnV_GAC': 116, 'ndhH': 116, 'ndhF': 116, 'ndhA': 116, 'trnT_UGU': 115, 'rpl32': 115, 'trnK_UUU': 115, 'ndhJ': 115, 'ndhI': 114, 'rps16': 111, 'trnS_CGA': 84, 'trnC_ACA': 59, 'psaM': 29, 'psb30': 27, 'trnP_GGG': 24, 'chlL': 24, 'chlN': 23, 'trnT_CGU': 23, 'chlB': 23, 'rpl21': 19, 'trnR_CCG': 16, 'trnI_AAU': 10, 'trnF_AAA': 7, 'trnfM_CAU': 5, 'trnY_AUA': 4, 'cysT': 4, 'trnS_AGA': 3, 'trnTERM_UUA': 3, 'trnnull_NNN': 3, 'trnR_UCG': 3, 'trnO_CUA': 3, 'trnL_AAG': 2, 'trnI_UAU': 2, 'trnG_ACC': 2, 'trnD_AUC': 2, 'trnK_CUU': 1, 'trnQ_CUG': 1, 'cysA': 1, 'trnA_AGC': 1, 'trnR_CCU': 1, 'trnT_AGU': 1, 'trnS_ACU': 1, 'trnL_CAG': 1}

# %%
# Remove outliers
for idx, record in enumerate(all_seqs):
    if (len(record) > gene_stats.loc[record.id.split('-')[1],:]['len_median']*2) | \
        (len(record) < gene_stats.loc[record.id.split('-')[1],:]['len_median']/2):
        print(record.id,'removed',len(record),gene_stats.loc[record.id.split('-')[1],:]['len_median'])
        del all_seqs[idx]
print(len(all_seqs))
# Out:
# NC_003386.1-cemA removed 1515 690.0
# NC_003386.1-trnL_UAA removed 472 85.0
# NC_005086.1-trnV_UAC removed 168 74.0
# NC_010323.1-infA removed 105 234.0
# NC_010654.1-trnS_UGA removed 402 93.0
# NC_011156.4-cysT removed 170 474.0
# NC_011156.4-ndhB removed 311 1533.0
# NC_011156.4-ndhD removed 114 1503.0
# NC_011156.4-rpl32 removed 456 171.0
# NC_011156.4-rps16 removed 66 261.0
# NC_011156.4-trnL_UAA removed 35 85.0
# NC_012818.1-cemA removed 1521 690.0
# NC_012818.1-clpP1 removed 273 591.0
# NC_012818.1-rpoB removed 696 3213.0
# NC_016986.1-rpl21 removed 39 360.0
# NC_016986.1-rpl23 removed 81 282.0
# NC_016986.1-trnS_AGA removed 336 108.0
# NC_017006.1-cemA removed 1518 690.0
# NC_017006.1-trnG_UCC removed 23 71.0
# NC_020146.1-cemA removed 1428 690.0
# NC_020146.1-rpl16 removed 81 408.0
# NC_020146.1-ycf2 removed 3409 6862.5
# NC_020146.1-trnL_UAA removed 345 85.0
# NC_022137.1-cemA removed 1533 690.0
# NC_022137.1-rps11 removed 168 417.0
# NC_024157.1-cemA removed 1521 690.0
# NC_024157.1-trnI_GAU removed 295 88.0
# NC_024158.1-cemA removed 1527 690.0
# NC_024158.1-rpoB removed 453 3213.0
# NC_024158.1-rps11 removed 156 417.0
# NC_024158.1-trnL_UAA removed 34 85.0
# NC_024929.1-infA removed 102 234.0
# NC_025745.1-infA removed 88 234.0
# NC_025745.1-rps16 removed 69 261.0
# NC_026295.1-accD removed 651 1476.0
# NC_026295.1-rps16 removed 69 261.0
# NC_026295.1-ycf1 removed 2155 5515.5
# NC_026295.1-trnL_UAA removed 372 85.0
# NC_026295.1-trnV_UAC removed 264 74.0
# NC_026301.1-chlL removed 267 874.5
# NC_026301.1-trnS_UGA removed 430 93.0
# NC_026301.1-trnV_UAC removed 265 74.0
# NC_026847.1-accD removed 718 1476.0
# NC_026847.1-ndhA removed 301 1092.0
# NC_026847.1-ndhD removed 234 1503.0
# NC_026847.1-rpl16 removed 9 408.0
# NC_026847.1-rpl23 removed 723 282.0
# NC_026847.1-rps12 removed 806 372.0
# NC_026847.1-ycf1 removed 466 5515.5
# NC_027829.1-ndhB removed 360 1533.0
# NC_027829.1-rpl33 removed 69 201.0
# NC_030601.1-rps7 removed 123 468.0
# NC_033874.1-cemA removed 1566 690.0
# NC_033874.1-ycf2 removed 3404 6862.5
# NC_033874.1-trnV_UAC removed 285 74.0
# NC_034686.1-rps16 removed 534 261.0
# NC_034942.1-ycf1 removed 2472 5515.5
# NC_034942.1-trnS_UGA removed 521 93.0
# NC_035050.1-ycf1 removed 807 5515.5
# NC_035499.1-cemA removed 174 690.0
# NC_035807.1-cemA removed 1515 690.0
# NC_035807.1-pafI removed 228 507.0
# NC_035807.1-trnL_UAA removed 34 85.0
# NC_035854.1-cemA removed 1500 690.0
# NC_035854.1-pafI removed 228 507.0
# NC_035854.1-rpoB removed 813 3213.0
# NC_035854.1-rps11 removed 168 417.0
# NC_035854.1-trnL_UAA removed 34 85.0
# NC_037151.1-infA removed 60 234.0
# NC_037504.1-trnS_UGA removed 447 93.0
# NC_037845.1-trnH_GUG removed 160572 75.0
# NC_038074.1-cemA removed 1500 690.0
# NC_038074.1-infA removed 78 234.0
# NC_038074.1-ndhJ removed 129 477.0
# NC_038074.1-rps16 removed 68 261.0
# NC_038074.1-rps2 removed 30 711.0
# NC_039155.1-accD removed 731 1476.0
# NC_039155.1-trnV_UAC removed 265 74.0
# NC_039395.1-infA removed 75 234.0
# NC_040219.1-cemA removed 1536 690.0
# NC_040219.1-ndhB removed 701 1533.0
# NC_040219.1-pafI removed 228 507.0
# NC_040219.1-trnL_UAA removed 34 85.0
# NC_040862.1-trnA_UGC removed 435 105.0
# NC_040862.1-trnH_GUG removed 121677 75.0
# NC_040862.1-trnL_UAA removed 366 85.0
# NC_041000.1-cemA removed 1473 690.0
# NC_041000.1-petA removed 12 963.0
# NC_041000.1-rpl16 removed 9 408.0
# NC_041000.1-ycf1 removed 2641 5515.5
# NC_041000.1-trnG_UCC removed 23 71.0
# NC_041261.1-accD removed 633 1476.0
# NC_041261.1-rpl23 removed 120 282.0
# NC_041466.1-accD removed 650 1476.0
# NC_041466.1-rps16 removed 524 261.0
# NC_041466.1-ycf1 removed 2246 5515.5
# NC_041466.1-trnA_UGC removed 35 105.0
# NC_041481.1-rpl2 removed 392 825.0
# NC_041640.1-rpl36 removed 600 114.0
# NC_042211.1-ycf1 removed 1257 5515.5
# NC_042597.1-infA removed 69 234.0
# NC_042597.1-ndhD removed 250 1503.0
# NC_042597.1-ndhG removed 162 531.0
# NC_042940.1-infA removed 102 234.0
# NC_042940.1-trnL_UAA removed 428 85.0
# NC_043796.1-ycf1 removed 744 5515.5
# NC_043796.1-trnA_UGC removed 302 105.0
# NC_043800.1-infA removed 24 234.0
# NC_045235.1-infA removed 108 234.0
# NC_045280.1-ndhA removed 469 1092.0
# NC_045280.1-ndhF removed 1055 2226.0
# NC_045280.1-ndhH removed 207 1182.0
# NC_045280.1-rpl16 removed 9 408.0
# NC_045280.1-rps16 removed 40 261.0
# NC_045280.1-trnH_GUG removed 148627 75.0
# NC_045294.1-accD removed 266 1476.0
# NC_046575.1-rpl23 removed 135 282.0
# NC_050270.1-infA removed 54 234.0
# NC_050270.1-rpl22 removed 141 426.0
# NC_051971.1-infA removed 78 234.0
# NC_051971.1-rps16 removed 40 261.0
# NC_051978.1-cemA removed 1524 690.0
# NC_052912.1-infA removed 108 234.0
# NC_054296.1-trnH_GUG removed 155479 75.0
# NC_054357.1-ycf1 removed 1496 5515.5
# NC_054357.1-trnS_UGA removed 375 93.0
# NC_054359.1-trnH_GUG removed 153356 75.0
# NC_054359.1-trnL_UAA removed 468 85.0
# 14085

# %%
ref_stats={}
for record in all_seqs:
    location = record.description.split('location=')[1].split(';')[0]
    ref_stats[record.id]={'len':len(record),'join':'join' in location,'forward':'+' in location,'reverse':'-' in location,
                         'location':location}
ref_stats = pd.DataFrame.from_dict(ref_stats,orient='index').reset_index().rename(columns={'index':'seqid'})
ref_stats[['Accession','gene']]=ref_stats.seqid.str.split('-',expand=True)
ref_stats['ls_loc'] = ref_stats.apply(lambda row: get_loc(row['location']),axis=1)
ref_stats['N_exons'] = ref_stats.apply(lambda row: len(row['ls_loc'])/2,axis=1)
gene_stats = ref_stats.groupby('gene').agg({'len':['min','median','max'],'Accession':['count'],
                                           'forward':['sum'],'reverse':['sum'],'join':['sum'],'N_exons':['mean']})
gene_stats.columns = ['_'.join(col).strip() for col in gene_stats.columns.values]
gene_stats.reset_index().to_csv(ref_dir + 'gene_stats.csv',index=False)
print(gene_stats.shape[0])
gene_stats[:2]
# Out:
# 144
#       len_min  len_median  len_max  Accession_count  forward_sum  reverse_sum  \
# gene
# accD      746      1476.0     1893              112          101           11
# atpA      882      1524.0     1545              124           14          110
#
#       join_sum  N_exons_mean
# gene
# accD         1      1.008929
# atpA         0      1.000000

# %%
gene_stats_clean = gene_stats[gene_stats.Accession_count>(gene_stats.Accession_count.max()*0.33)].astype({'len_median':'int'})
gene_stats_clean['N_exons_mean'] = gene_stats_clean['N_exons_mean'].round(2)
gene_stats_clean.reset_index().to_csv(ref_dir + 'cleaned_gene_stats.csv',index=False)
print(gene_stats_clean.shape[0],gene_stats_clean.Accession_count.sort_values(ascending=False).to_dict())
gene_stats_clean
# Out:
# 113 {'psaI': 124, 'psaB': 124, 'rps19': 124, 'psaJ': 124, 'psbA': 124, 'psbB': 124, 'psbC': 124, 'psbD': 124, 'psbE': 124, 'psbF': 124, 'psbH': 124, 'psbI': 124, 'psbK': 124, 'psbL': 124, 'psbM': 124, 'psbT': 124, 'psbZ': 124, 'rbcL': 124, 'rpl14': 124, 'rrn4.5': 124, 'rrn23': 124, 'rpl20': 124, 'atpA': 124, 'rrn16': 124, 'rps8': 124, 'rpoA': 124, 'rpoC1': 124, 'rpoC2': 124, 'rps4': 124, 'rps14': 124, 'rps3': 124, 'psaC': 124, 'rps18': 124, 'psaA': 124, 'trnE_UUC': 124, 'atpB': 124, 'atpE': 124, 'atpF': 124, 'atpH': 124, 'atpI': 124, 'ccsA': 124, 'trnY_GUA': 124, 'trnW_CCA': 124, 'trnR_ACG': 124, 'petN': 124, 'trnM_CAU': 124, 'trnQ_UUG': 124, 'pbf1': 124, 'petG': 124, 'trnD_GUC': 124, 'trnC_GCA': 124, 'petD': 124, 'petB': 124, 'rrn5': 124, 'pafII': 124, 'trnF_GAA': 123, 'rps2': 123, 'petL': 123, 'rps12': 123, 'petA': 123, 'rps7': 123, 'rpl33': 123, 'rpl36': 123, 'trnL_UAG': 123, 'trnS_GCU': 123, 'trnR_UCU': 123, 'trnP_UGG': 123, 'trnN_GUU': 123, 'psbJ': 123, 'trnS_GGA': 122, 'rpl22': 122, 'ycf2': 122, 'matK': 122, 'rpl2': 122, 'trnL_CAA': 121, 'trnG_GCC': 121, 'rps11': 121, 'rpoB': 121, 'pafI': 121, 'clpP1': 120, 'rpl16': 120, 'trnA_UGC': 120, 'rps15': 120, 'trnI_GAU': 120, 'trnH_GUG': 119, 'trnT_GGU': 119, 'trnS_UGA': 118, 'ndhE': 117, 'trnG_UCC': 117, 'ndhC': 117, 'rpl23': 117, 'trnV_GAC': 116, 'ndhK': 116, 'ndhB': 116, 'ndhG': 116, 'ndhD': 116, 'ndhF': 115, 'ndhH': 115, 'trnK_UUU': 115, 'trnT_UGU': 115, 'ndhA': 114, 'rpl32': 114, 'ndhJ': 114, 'ndhI': 114, 'ycf1': 113, 'trnV_UAC': 113, 'accD': 112, 'trnL_UAA': 112, 'cemA': 108, 'infA': 105, 'rps16': 103, 'trnS_CGA': 84, 'trnC_ACA': 59}
#           len_min  len_median  len_max  Accession_count  forward_sum  \
# gene
# accD          746        1476     1893              112          101
# atpA          882        1524     1545              124           14
# atpB          849        1497     1520              124           12
# atpE          396         402      450              124           13
# atpF          424         555      576              124           13
# ...           ...         ...      ...              ...          ...
# trnV_UAC       37          74      119              113            9
# trnW_CCA       74          74       76              124           11
# trnY_GUA       82          86       89              124           16
# ycf1         3164        5538     6951              113           29
# ycf2          255        6865     7374              122           67
#
#           reverse_sum  join_sum  N_exons_mean
# gene
# accD               11         1          1.01
# atpA              110         0          1.00
# atpB              112         0          1.00
# atpE              111         0          1.00
# atpF              111       123          1.99
# ...               ...       ...           ...
# trnV_UAC          104       104          1.92
# trnW_CCA          113         1          1.01
# trnY_GUA          108         0          1.00
# ycf1               84         1          1.01
# ycf2               55         0          1.00
#
# [113 rows x 8 columns]

# %%
# Remove genes not kept
for idx, record in enumerate(all_seqs):
    if (record.id.split('-')[1] not in gene_stats_clean.index):
        print(record.id,'removed',end=', ')
        del all_seqs[idx]
print(len(all_seqs))
# Out:
# psaM removed, rpl21 removed, trnF_AAA removed, trnP_GGG removed, trnR_CCG removed, trnT_CGU removed, psb30 removed, trnS_AGA removed, psb30 removed, trnG_ACC removed, trnP_GGG removed, trnR_CCG removed, chlB removed, chlN removed, psaM removed, trnP_GGG removed, trnR_CCG removed, trnY_AUA removed, trnfM_CAU removed, chlB removed, chlN removed, psaM removed, rpl21 removed, trnP_GGG removed, trnR_UCG removed, trnT_AGU removed, chlB removed, chlN removed, psaM removed, trnP_GGG removed, trnR_CCG removed, trnY_AUA removed, trnfM_CAU removed, chlB removed, chlN removed, psaM removed, rpl21 removed, trnP_GGG removed, trnR_CCG removed, chlB removed, chlN removed, psaM removed, rpl21 removed, trnD_AUC removed, trnP_GGG removed, trnR_CCG removed, chlB removed, chlN removed, psaM removed, rpl21 removed, trnA_AGC removed, trnP_GGG removed, chlB removed, chlN removed, psaM removed, rpl21 removed, trnK_CUU removed, trnP_GGG removed, trnR_CCG removed, trnT_CGU removed, chlB removed, chlN removed, psaM removed, rpl21 removed, trnP_GGG removed, trnR_CCG removed, trnI_AAU removed, trnO_CUA removed, trnT_CGU removed, trnY_AUA removed, chlB removed, chlN removed, psaM removed, trnI_AAU removed, trnP_GGG removed, trnTERM_UUA removed, psb30 removed, trnG_ACC removed, trnP_GGG removed, trnR_CCG removed, trnT_CGU removed, trnS_ACU removed, chlB removed, chlN removed, cysT removed, psaM removed, rpl21 removed, trnP_GGG removed, trnR_CCG removed, trnfM_CAU removed, trnT_CGU removed, trnT_CGU removed, chlB removed, chlN removed, cysT removed, psaM removed, rpl21 removed, trnP_GGG removed, trnR_CCG removed, psaM removed, trnT_CGU removed, chlB removed, chlN removed, psaM removed, trnO_CUA removed, trnR_CCG removed, trnT_CGU removed, trnI_AAU removed, psaM removed, chlB removed, chlN removed, psb30 removed, rpl21 removed, trnP_GGG removed, chlB removed, chlN removed, psaM removed, rpl21 removed, trnP_GGG removed, trnnull_NNN removed, trnT_CGU removed, trnT_CGU removed, trnTERM_UUA removed, psaM removed, psb30 removed, trnI_AAU removed, trnI_AAU removed, chlB removed, chlN removed, psaM removed, rpl21 removed, trnP_GGG removed, trnQ_CUG removed, trnT_CGU removed, trnnull_NNN removed, chlB removed, chlN removed, psaM removed, rpl21 removed, trnF_AAA removed, trnP_GGG removed, trnR_CCG removed, trnT_CGU removed, psaM removed, trnF_AAA removed, trnF_AAA removed, trnT_CGU removed, chlB removed, chlN removed, psb30 removed, rpl21 removed, trnP_GGG removed, trnY_AUA removed, chlB removed, chlN removed, psaM removed, rpl21 removed, trnL_CAG removed, trnP_GGG removed, trnR_CCG removed, trnT_CGU removed, psaM removed, trnF_AAA removed, trnT_CGU removed, trnI_AAU removed, trnS_AGA removed, trnT_CGU removed, chlB removed, chlN removed, psaM removed, trnI_AAU removed, trnI_UAU removed, trnP_GGG removed, trnR_UCG removed, trnI_UAU removed, chlB removed, chlN removed, cysA removed, psb30 removed, rpl21 removed, trnR_CCU removed, trnfM_CAU removed, trnI_AAU removed, trnI_AAU removed, trnL_AAG removed, trnI_AAU removed, psaM removed, trnT_CGU removed, psaM removed, trnF_AAA removed, trnT_CGU removed, trnR_UCG removed, psaM removed, trnTERM_UUA removed, psb30 removed, trnO_CUA removed, trnF_AAA removed, chlB removed, chlN removed, psaM removed, rpl21 removed, trnD_AUC removed, trnP_GGG removed, trnR_CCG removed, trnL_AAG removed, chlB removed, chlN removed, cysT removed, psaM removed, rpl21 removed, trnP_GGG removed, trnR_CCG removed, trnT_CGU removed, trnfM_CAU removed, trnT_CGU removed, trnT_CGU removed, trnT_CGU removed, chlB removed, chlN removed, psaM removed, 13865

# %%
# Remove duplicates
ls_id = []
for idx, record in enumerate(all_seqs):
    if record.id in ls_id:
        print(record.id,'removed',end=', ')
        del all_seqs[idx]
    else:
        ls_id.append(record.id)
print(len(all_seqs))
# Out:
# 13632

# %%
SeqIO.write(all_seqs,ref_dir + 'cpDNA_RefCDS.fasta',format='fasta')
# Out:
# 13632

# %%
Multi_Exons = gene_stats_clean[(gene_stats_clean.N_exons_mean>1.33)]
print(Multi_Exons.index)
Multi_Exons
# Out:
# Index(['atpF', 'clpP1', 'ndhA', 'ndhB', 'pafI', 'petB', 'petD', 'rpl16',
#        'rpl2', 'rpoC1', 'rps12', 'rps16', 'trnC_ACA', 'trnG_UCC', 'trnK_UUU',
#        'trnL_UAA', 'trnS_CGA', 'trnV_UAC'],
#       dtype='object', name='gene')
#           len_min  len_median  len_max  Accession_count  forward_sum  \
# gene
# atpF          424         555      576              124           13
# clpP1         323         591      948              120           10
# ndhA          574        1092     1119              114           22
# ndhB          773        1533     1569              116           44
# pafI          283         507      543              121           11
# petB          489         648      708              124          116
# petD          479         483      539              124          116
# rpl16         392         408      492              120            7
# rpl2          462         825      849              122           57
# rpoC1        1359        2049     2118              124           14
# rps12         232         372      723              123           80
# rps16         143         261      276              103            3
# trnC_ACA       72          95       97               59            3
# trnG_UCC       48          71       92              117          106
# trnK_UUU       37          72       90              115            6
# trnL_UAA       84          85       89              112          103
# trnS_CGA       70          92       94               84           75
# trnV_UAC       37          74      119              113            9
#
#           reverse_sum  join_sum  N_exons_mean
# gene
# atpF              111       123          1.99
# clpP1             110       106          2.74
# ndhA               92       113          1.99
# ndhB               72       113          1.97
# pafI              110       121          2.99
# petB                8       113          1.91
# petD                8        90          1.73
# rpl16             113       102          1.85
# rpl2               65       117          1.97
# rpoC1             110       118          1.95
# rps12             114       118          2.89
# rps16             100        90          1.87
# trnC_ACA           56        57          1.97
# trnG_UCC           11       116          1.99
# trnK_UUU          109       112          1.97
# trnL_UAA            9       112          2.00
# trnS_CGA            9        77          1.92
# trnV_UAC          104       104          1.92

# %% [markdown]
# Run 'makeblastdb -in References/cpDNA_RefCDS.fasta -dbtype nucl -parse_seqids'

# %% [markdown]
# blastn  -query ../GetOrganelles/PAFTOL/fasta_pt/PAFTOL_016977_pt.fasta  -db References/cpDNA_RefGenes.fasta -outfmt "6 qseqid sseqid pident length mismatch gapopen qlen qstart qend slen sstart send evalue bitscore qseq" -out PAFTOL_016977.blast -max_target_seqs 5 -num_threads 1 -gapopen 0 -gapextend 0
#
# python targets_from_blast.py PAFTOL_016977.blast PAFTOL_016977_ptGenes.fasta
